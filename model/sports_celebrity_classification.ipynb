# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/chiranjeevi.jpg')
img.shape
# Out:
# (402, 302, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (402, 302)

# %%
gray
# Out:
# array([[ 67,  67,  67, ...,  73,  74,  73],
#        [ 67,  67,  67, ...,  73,  74,  73],
#        [ 68,  68,  68, ...,  73,  74,  73],
#        ...,
#        [ 38,  33,  30, ..., 218, 217, 217],
#        [ 36,  37,  30, ..., 217, 217, 216],
#        [ 34,  35,  28, ..., 217, 217, 216]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 61,  67, 162, 162]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (61, 67, 162, 162)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (162, 162, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/chiranjeevi.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/chiranjeevi.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/chiranjeevi2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/chiranjeevi2.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/ram_charan',
#  './dataset/prabhas',
#  './dataset/nani',
#  './dataset/deepika_padukone',
#  './dataset/chiranjeevi',
#  './dataset/priyanka_chopra']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/ram_charan
# Generating cropped images in folder:  ./dataset/cropped/prabhas
# Generating cropped images in folder:  ./dataset/cropped/nani
# Generating cropped images in folder:  ./dataset/cropped/deepika_padukone
# Generating cropped images in folder:  ./dataset/cropped/chiranjeevi
# Generating cropped images in folder:  ./dataset/cropped/priyanka_chopra

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'ram_charan': ['./dataset/cropped/ram_charan/ram_charan11.png',
#   './dataset/cropped/ram_charan/ram_charan10.png',
#   './dataset/cropped/ram_charan/ram_charan12.png',
#   './dataset/cropped/ram_charan/ram_charan13.png',
#   './dataset/cropped/ram_charan/ram_charan8.png',
#   './dataset/cropped/ram_charan/ram_charan17.png',
#   './dataset/cropped/ram_charan/ram_charan16.png',
#   './dataset/cropped/ram_charan/ram_charan9.png',
#   './dataset/cropped/ram_charan/ram_charan28.png',
#   './dataset/cropped/ram_charan/ram_charan14.png',
#   './dataset/cropped/ram_charan/ram_charan15.png',
#   './dataset/cropped/ram_charan/ram_charan29.png',
#   './dataset/cropped/ram_charan/ram_charan7.png',
#   './dataset/cropped/ram_charan/ram_charan24.png',
#   './dataset/cropped/ram_charan/ram_charan30.png',
#   './dataset/cropped/ram_charan/ram_charan18.png',
#   './dataset/cropped/ram_charan/ram_charan19.png',
#   './dataset/cropped/ram_charan/ram_charan31.png',
#   './dataset/cropped/ram_charan/ram_charan25.png',
#   './dataset/cropped/ram_charan/ram_charan6.png',
#   './dataset/cropped/ram_charan/ram_charan4.png',
#   './dataset/cropped/ram_charan/ram_charan33.png',
#   './dataset/cropped/ram_charan/ram_charan27.png',
#   './dataset/cropped/ram_charan/ram_charan26.png',
#   './dataset/cropped/ram_charan/ram_charan32.png',
#   './dataset/cropped/ram_charan/ram_charan5.png',
#   './dataset/cropped/ram_charan/ram_charan1.png',
#   './dataset/cropped/ram_charan/ram_charan36.png',
#   './dataset/cropped/ram_charan/ram_charan22.png',
#   './dataset/cropped/ram_charan/ram_charan23.png',
#   './dataset/cropped/ram_charan/ram_charan2.png',
#   './dataset/cropped/ram_charan/ram_charan21.png',
#   './dataset/cropped/ram_charan/ram_charan35.png',
#   './dataset/cropped/ram_charan/ram_charan34.png',
#   './dataset/cropped/ram_charan/ram_charan20.png',
#   './dataset/cropped/ram_charan/ram_charan3.png'],
#  'prabhas': ['./dataset/cropped/prabhas/prabhas4.png',
#   './dataset/cropped/prabhas/prabhas5.png',
#   './dataset/cropped/prabhas/prabhas7.png',
#   './dataset/cropped/prabhas/prabhas6.png',
#   './dataset/cropped/prabhas/prabhas2.png',
#   './dataset/cropped/prabhas/prabhas3.png',
#   './dataset/cropped/prabhas/prabhas1.png',
#   './dataset/cropped/prabhas/prabhas15.png',
#   './dataset/cropped/prabhas/prabhas14.png',
#   './dataset/cropped/prabhas/prabhas16.png',
#   './dataset/cropped/prabhas/prabhas17.png',
#   './dataset/cropped/prabhas/prabhas13.png',
#   './dataset/cropped/prabhas/prabhas12.png',
#   './dataset/cropped/prabhas/prabhas10.png',
#   './dataset/cropped/prabhas/prabhas11.png',
#   './dataset/cropped/prabhas/prabhas20.png',
#   './dataset/cropped/prabhas/prabhas21.png',
#   './dataset/cropped/prabhas/prabhas23.png',
#   './dataset/cropped/prabhas/prabhas22.png',
#   './dataset/cropped/prabhas/prabhas19.png',
#   './dataset/cropped/prabhas/prabhas18.png',
#   './dataset/cropped/prabhas/prabhas8.png',
#   './dataset/cropped/prabhas/prabhas9.png'],
#  'nani': ['./dataset/cropped/nani/nani24.png',
#   './dataset/cropped/nani/nani3.png',
#   './dataset/cropped/nani/nani30.png',
#   './dataset/cropped/nani/nani18.png',
#   './dataset/cropped/nani/nani19.png',
#   './dataset/cropped/nani/nani2.png',
#   './dataset/cropped/nani/nani31.png',
#   './dataset/cropped/nani/nani25.png',
#   './dataset/cropped/nani/nani33.png',
#   './dataset/cropped/nani/nani27.png',
#   './dataset/cropped/nani/nani26.png',
#   './dataset/cropped/nani/nani32.png',
#   './dataset/cropped/nani/nani1.png',
#   './dataset/cropped/nani/nani5.png',
#   './dataset/cropped/nani/nani36.png',
#   './dataset/cropped/nani/nani22.png',
#   './dataset/cropped/nani/nani23.png',
#   './dataset/cropped/nani/nani4.png',
#   './dataset/cropped/nani/nani37.png',
#   './dataset/cropped/nani/nani21.png',
#   './dataset/cropped/nani/nani35.png',
#   './dataset/cropped/nani/nani6.png',
#   './dataset/cropped/nani/nani34.png',
#   './dataset/cropped/nani/nani7.png',
#   './dataset/cropped/nani/nani20.png',
#   './dataset/cropped/nani/nani11.png',
#   './dataset/cropped/nani/nani38.png',
#   './dataset/cropped/nani/nani10.png',
#   './dataset/cropped/nani/nani12.png',
#   './dataset/cropped/nani/nani9.png',
#   './dataset/cropped/nani/nani8.png',
#   './dataset/cropped/nani/nani13.png',
#   './dataset/cropped/nani/nani17.png',
#   './dataset/cropped/nani/nani16.png',
#   './dataset/cropped/nani/nani28.png',
#   './dataset/cropped/nani/nani14.png',
#   './dataset/cropped/nani/nani15.png',
#   './dataset/cropped/nani/nani29.png'],
#  'deepika_padukone': ['./dataset/cropped/deepika_padukone/deepika_padukone17.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone16.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone28.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone14.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone15.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone29.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone11.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone10.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone12.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone13.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone8.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone9.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone2.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone3.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone1.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone4.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone5.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone7.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone6.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone22.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone23.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone21.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone20.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone24.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone30.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone18.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone19.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone31.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone25.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone27.png',
#   './dataset/cropped/deepika_padukone/deepika_padukone26.png'],
#  'chiranjeevi': ['./dataset/cropped/chiranjeevi/chiranjeevi9.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi8.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi11.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi10.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi12.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi13.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi17.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi16.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi28.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi14.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi15.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi24.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi18.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi19.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi25.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi27.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi26.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi22.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi23.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi21.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi20.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi6.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi7.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi5.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi4.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi1.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi3.png',
#   './dataset/cropped/chiranjeevi/chiranjeevi2.png'],
#  'priyanka_chopra': ['./dataset/cropped/priyanka_chopra/priyanka_chopra13.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra12.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra38.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra10.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra8.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra9.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra11.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra15.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra29.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra28.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra14.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra16.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra17.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra26.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra32.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra2.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra3.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra33.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra27.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra19.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra31.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra25.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra1.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra24.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra30.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra18.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra34.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra20.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra4.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra5.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra21.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra35.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra23.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra37.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra7.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra6.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra36.png',
#   './dataset/cropped/priyanka_chopra/priyanka_chopra22.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'ram_charan': 0,
#  'prabhas': 1,
#  'nani': 2,
#  'deepika_padukone': 3,
#  'chiranjeevi': 4,
#  'priyanka_chopra': 5}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[26],
#        [22],
#        [33],
#        ...,
#        [ 9],
#        [96],
#        [21]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (194, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.6530612244897959

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.37      0.78      0.50         9
#            1       1.00      0.40      0.57         5
#            2       0.62      0.62      0.62         8
#            3       0.80      0.67      0.73         6
#            4       1.00      0.62      0.77         8
#            5       0.90      0.69      0.78        13
#
#     accuracy                           0.65        49
#    macro avg       0.78      0.63      0.66        49
# weighted avg       0.77      0.65      0.67        49

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.737931
# 1        random_forest    0.524138
# 2  logistic_regression    0.779310
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7346938775510204

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5510204081632653

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7755102040816326

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[8, 0, 1, 0, 0, 0],
#        [1, 4, 0, 0, 0, 0],
#        [2, 0, 6, 0, 0, 0],
#        [0, 0, 1, 4, 0, 1],
#        [2, 0, 1, 0, 5, 0],
#        [2, 0, 1, 1, 0, 9]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'ram_charan': 0,
#  'prabhas': 1,
#  'nani': 2,
#  'deepika_padukone': 3,
#  'chiranjeevi': 4,
#  'priyanka_chopra': 5}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (1.4.2)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
